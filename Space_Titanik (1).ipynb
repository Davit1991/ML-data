# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False  \
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df_test
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP
# 0        0013_01      Earth      True     G/3/S    TRAPPIST-1e  27.0  False  \
# 1        0018_01      Earth     False     F/4/S    TRAPPIST-1e  19.0  False
# 2        0019_01     Europa      True     C/0/S    55 Cancri e  31.0  False
# 3        0021_01     Europa     False     C/1/S    TRAPPIST-1e  38.0  False
# 4        0023_01      Earth     False     F/5/S    TRAPPIST-1e  20.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 4272     9266_02      Earth      True  G/1496/S    TRAPPIST-1e  34.0  False
# 4273     9269_01      Earth     False       NaN    TRAPPIST-1e  42.0  False
# 4274     9271_01       Mars      True   D/296/P    55 Cancri e   NaN  False
# 4275     9273_01     Europa     False   D/297/P            NaN   NaN  False
# 4276     9277_01      Earth      True  G/1498/S  PSO J318.5-22  43.0  False
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8492 non-null   object
#  2   CryoSleep     8476 non-null   object
#  3   Cabin         8494 non-null   object
#  4   Destination   8511 non-null   object
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   object
#  13  Transported   8693 non-null   bool
# dtypes: bool(1), float64(6), object(7)
# memory usage: 891.5+ KB

# %%
df_train.isna().sum()
# Out:
# PassengerId       0
# HomePlanet      201
# CryoSleep       217
# Cabin           199
# Destination     182
# Age             179
# VIP             203
# RoomService     181
# FoodCourt       183
# ShoppingMall    208
# Spa             183
# VRDeck          188
# Name            200
# Transported       0
# dtype: int64

# %%
df_train
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False  \
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df_train = df_train.drop('PassengerId', axis=1)

# %%
df_train
# Out:
#      HomePlanet CryoSleep     Cabin    Destination   Age    VIP  RoomService
# 0        Europa     False     B/0/P    TRAPPIST-1e  39.0  False          0.0  \
# 1         Earth     False     F/0/S    TRAPPIST-1e  24.0  False        109.0
# 2        Europa     False     A/0/S    TRAPPIST-1e  58.0   True         43.0
# 3        Europa     False     A/0/S    TRAPPIST-1e  33.0  False          0.0
# 4         Earth     False     F/1/S    TRAPPIST-1e  16.0  False        303.0
# ...         ...       ...       ...            ...   ...    ...          ...
# 8688     Europa     False    A/98/P    55 Cancri e  41.0   True          0.0
# 8689      Earth      True  G/1499/S  PSO J318.5-22  18.0  False          0.0
# 8690      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False          0.0
# 8691     Europa     False   E/608/S    55 Cancri e  32.0  False          0.0
# 8692     Europa     False   E/608/S    TRAPPIST-1e  44.0  False        126.0
#
# ...

# %%
df_train['HomePlanet'].unique()
# Out:
# array(['Europa', 'Earth', 'Mars', nan], dtype=object)

# %%
df_train['HomePlanet'].isna().sum()
# Out:
# 201

# %%
df_train = df_train.dropna(thresh=1)

# %%
df_train['HomePlanet'].isna().sum()
# Out:
# 201

# %%
len(df_train)
# Out:
# 8693

# %%
df_train['HomePlanet']
# Out:
# 0       Europa
# 1        Earth
# 2       Europa
# 3       Europa
# 4        Earth
#          ...
# 8688    Europa
# 8689     Earth
# 8690     Earth
# 8691    Europa
# 8692    Europa
# Name: HomePlanet, Length: 8693, dtype: object

# %%
sns.countplot(x=df_train['HomePlanet'], hue=df_train['Transported'])
# Out:
# <Axes: xlabel='HomePlanet', ylabel='count'>

# %%
df_train[df_train['HomePlanet'].isna()]
# Out:
#      HomePlanet CryoSleep     Cabin  Destination   Age    VIP  RoomService
# 59          NaN      True     E/3/S  TRAPPIST-1e  33.0  False          0.0  \
# 113         NaN     False     A/0/P  TRAPPIST-1e  39.0  False          0.0
# 186         NaN      True     D/6/P  55 Cancri e  24.0  False          0.0
# 225         NaN     False    F/46/S  TRAPPIST-1e  18.0  False        313.0
# 234         NaN      True    C/11/S  55 Cancri e  54.0  False          0.0
# ...         ...       ...       ...          ...   ...    ...          ...
# 8515        NaN     False   E/582/P  TRAPPIST-1e  25.0  False       1258.0
# 8613        NaN     False   E/603/S  55 Cancri e  53.0  False          0.0
# 8666        NaN     False  F/1792/S  55 Cancri e  38.0    NaN         28.0
# 8674        NaN     False  F/1892/P  TRAPPIST-1e  13.0  False         39.0
# 8684        NaN      True  G/1508/P  TRAPPIST-1e  23.0  False          0.0
#
# ...

# %%
df_train[df_train['HomePlanet'] == 'Europa']
# Out:
#      HomePlanet CryoSleep    Cabin  Destination   Age    VIP  RoomService
# 0        Europa     False    B/0/P  TRAPPIST-1e  39.0  False          0.0  \
# 2        Europa     False    A/0/S  TRAPPIST-1e  58.0   True         43.0
# 3        Europa     False    A/0/S  TRAPPIST-1e  33.0  False          0.0
# 9        Europa      True    B/1/P  55 Cancri e  14.0  False          0.0
# 10       Europa      True    B/1/P  TRAPPIST-1e  34.0  False          0.0
# ...         ...       ...      ...          ...   ...    ...          ...
# 8686     Europa     False   A/97/P  TRAPPIST-1e  32.0  False          1.0
# 8687     Europa       NaN   A/97/P  TRAPPIST-1e  30.0  False          0.0
# 8688     Europa     False   A/98/P  55 Cancri e  41.0   True          0.0
# 8691     Europa     False  E/608/S  55 Cancri e  32.0  False          0.0
# 8692     Europa     False  E/608/S  TRAPPIST-1e  44.0  False        126.0
#
#       FoodCourt  ShoppingMall     Spa  VRDeck               Name  Transported
# ...

# %%
df_train = df_train.dropna()

# %%
df_train.isna().sum()
# Out:
# HomePlanet      0
# CryoSleep       0
# Cabin           0
# Destination     0
# Age             0
# VIP             0
# RoomService     0
# FoodCourt       0
# ShoppingMall    0
# Spa             0
# VRDeck          0
# Name            0
# Transported     0
# dtype: int64

# %%
df_train
# Out:
#      HomePlanet CryoSleep     Cabin    Destination   Age    VIP  RoomService
# 0        Europa     False     B/0/P    TRAPPIST-1e  39.0  False          0.0  \
# 1         Earth     False     F/0/S    TRAPPIST-1e  24.0  False        109.0
# 2        Europa     False     A/0/S    TRAPPIST-1e  58.0   True         43.0
# 3        Europa     False     A/0/S    TRAPPIST-1e  33.0  False          0.0
# 4         Earth     False     F/1/S    TRAPPIST-1e  16.0  False        303.0
# ...         ...       ...       ...            ...   ...    ...          ...
# 8688     Europa     False    A/98/P    55 Cancri e  41.0   True          0.0
# 8689      Earth      True  G/1499/S  PSO J318.5-22  18.0  False          0.0
# 8690      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False          0.0
# 8691     Europa     False   E/608/S    55 Cancri e  32.0  False          0.0
# 8692     Europa     False   E/608/S    TRAPPIST-1e  44.0  False        126.0
#
# ...

# %%
df_train = df_train.drop('Destination', axis=1)
df_train = df_train.drop('Name', axis=1)

# %%
df_train = df_train.drop('Cabin', axis=1)
df_train['HomePlanet'] = df_train['HomePlanet'].replace(to_replace='Europa', value=0)
df_train['HomePlanet'] = df_train['HomePlanet'].replace(to_replace='Earth', value=1)
df_train['HomePlanet'] = df_train['HomePlanet'].replace(to_replace='Mars', value=2)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6606 entries, 0 to 8692
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HomePlanet    6606 non-null   int64
#  1   CryoSleep     6606 non-null   object
#  2   Age           6606 non-null   float64
#  3   VIP           6606 non-null   object
#  4   RoomService   6606 non-null   float64
#  5   FoodCourt     6606 non-null   float64
#  6   ShoppingMall  6606 non-null   float64
#  7   Spa           6606 non-null   float64
#  8   VRDeck        6606 non-null   float64
#  9   Transported   6606 non-null   bool
# dtypes: bool(1), float64(6), int64(1), object(2)
# memory usage: 522.5+ KB

# %%
df_train.corr()['Transported']
# Out:
# HomePlanet     -0.109551
# CryoSleep       0.462803
# Age            -0.082553
# VIP            -0.042260
# RoomService    -0.247291
# FoodCourt       0.055025
# ShoppingMall    0.011602
# Spa            -0.219854
# VRDeck         -0.207950
# Transported     1.000000
# Name: Transported, dtype: float64

# %%
df_train
# Out:
#       HomePlanet CryoSleep   Age    VIP  RoomService  FoodCourt  ShoppingMall
# 0              0     False  39.0  False          0.0        0.0           0.0  \
# 1              1     False  24.0  False        109.0        9.0          25.0
# 2              0     False  58.0   True         43.0     3576.0           0.0
# 3              0     False  33.0  False          0.0     1283.0         371.0
# 4              1     False  16.0  False        303.0       70.0         151.0
# ...          ...       ...   ...    ...          ...        ...           ...
# 8688           0     False  41.0   True          0.0     6819.0           0.0
# 8689           1      True  18.0  False          0.0        0.0           0.0
# 8690           1     False  26.0  False          0.0        0.0        1872.0
# 8691           0     False  32.0  False          0.0     1049.0           0.0
# 8692           0     False  44.0  False        126.0     4688.0           0.0
#
# ...

# %%
X_train = df_train.drop('Transported', axis=1)
y_train = df_train['Transported']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
model = RandomForestClassifier()
scaler = StandardScaler()

# %%
pipe = Pipeline([('scaler', scaler), ('rfc', model)])

# %%
params = {
    'rfc__n_estimators':list(range(70, 75)),
    'rfc__criterion':["gini", "entropy", "log_loss"],
    'rfc__max_depth':[2, 4, 8, 32],
    'rfc__max_features':["sqrt", "log2", "auto"],
    'rfc__bootstrap':[True, False],
    'rfc__oob_score':[True, False]
}

# %%
full_model = GridSearchCV(pipe, param_grid=params, cv=3, verbose=2, scoring='accuracy')

# %%
full_model.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 720 candidates, totalling 2160 fits
# [CV] END rfc__bootstrap=True, rfc__criterion=gini, rfc__max_depth=2, rfc__max_features=sqrt, rfc__n_estimators=70, rfc__oob_score=True; total time=   0.2s
# [CV] END rfc__bootstrap=True, rfc__criterion=gini, rfc__max_depth=2, rfc__max_features=sqrt, rfc__n_estimators=70, rfc__oob_score=True; total time=   0.1s
# [CV] END rfc__bootstrap=True, rfc__criterion=gini, rfc__max_depth=2, rfc__max_features=sqrt, rfc__n_estimators=70, rfc__oob_score=True; total time=   0.1s
# [CV] END rfc__bootstrap=True, rfc__criterion=gini, rfc__max_depth=2, rfc__max_features=sqrt, rfc__n_estimators=70, rfc__oob_score=False; total time=   0.1s
# [CV] END rfc__bootstrap=True, rfc__criterion=gini, rfc__max_depth=2, rfc__max_features=sqrt, rfc__n_estimators=70, rfc__oob_score=False; total time=   0.1s
# ...

# %%
full_model.cv_results_
# Out:
# {'mean_fit_time': array([0.22923605, 0.18240301, 0.22904078, 0.28794233, 0.27974621,
#         0.1766096 , 0.21262805, 0.1737589 , 0.21607216, 0.18039529,
#         0.20662896, 0.16861939, 0.20331542, 0.16841404, 0.21301858,
#         0.17760603, 0.2190388 , 0.18138655, 0.22934461, 0.1773924 ,
#         0.21414582, 0.17997169, 0.21532265, 0.18074958, 0.22090753,
#         0.18349584, 0.23061728, 0.21691298, 0.25784969, 0.26029237,
#         0.27193586, 0.22870644, 0.26989285, 0.23324021, 0.27566632,
#         0.23330402, 0.26491078, 0.22366087, 0.27061296, 0.22672168,
#         0.25753387, 0.22374638, 0.26194342, 0.21625026, 0.25991209,
#         0.2249345 , 0.26265756, 0.24824095, 0.27988156, 0.22736422,
#         0.27745279, 0.23617172, 0.27118635, 0.22708241, 0.27906251,
#         0.22943823, 0.27924506, 0.22808472, 0.27706758, 0.2343092 ,
#         0.34083247, 0.29165832, 0.33427993, 0.29761442, 0.34410175,
#         0.297074  , 0.35933789, 0.31217766, 0.3502086 , 0.30831575,
# ...

# %%
full_model.best_params_
# Out:
# {'rfc__bootstrap': True,
#  'rfc__criterion': 'log_loss',
#  'rfc__max_depth': 8,
#  'rfc__max_features': 'auto',
#  'rfc__n_estimators': 72,
#  'rfc__oob_score': True}

# %%
y_pred_val = full_model.predict(X_val)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_pred_val, y_val))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.78      0.82      0.80       920
#         True       0.84      0.79      0.82      1062
#
#     accuracy                           0.81      1982
#    macro avg       0.81      0.81      0.81      1982
# weighted avg       0.81      0.81      0.81      1982

# %%
df_test.isna().sum()
# Out:
# PassengerId       0
# HomePlanet       87
# CryoSleep        93
# Cabin           100
# Destination      92
# Age              91
# VIP              93
# RoomService      82
# FoodCourt       106
# ShoppingMall     98
# Spa             101
# VRDeck           80
# Name             94
# dtype: int64

# %%
len(df_test)
# Out:
# 4277

# %%
df_test = df_test.drop('Destination', axis=1)
df_test = df_test.drop('Name', axis=1)

# %%
df_test = df_test.drop('Cabin', axis=1)
df_test['HomePlanet'] = df_test['HomePlanet'].replace(to_replace='Europa', value=0)
df_test['HomePlanet'] = df_test['HomePlanet'].replace(to_replace='Earth', value=1)
df_test['HomePlanet'] = df_test['HomePlanet'].replace(to_replace='Mars', value=2)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4277 entries, 0 to 4276
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   4277 non-null   object
#  1   HomePlanet    4190 non-null   float64
#  2   CryoSleep     4184 non-null   object
#  3   Age           4186 non-null   float64
#  4   VIP           4184 non-null   object
#  5   RoomService   4195 non-null   float64
#  6   FoodCourt     4171 non-null   float64
#  7   ShoppingMall  4179 non-null   float64
#  8   Spa           4176 non-null   float64
#  9   VRDeck        4197 non-null   float64
# dtypes: float64(7), object(3)
# memory usage: 334.3+ KB

# %%
df_test.isna().sum()
# Out:
# PassengerId     0
# HomePlanet      0
# CryoSleep       0
# Age             0
# VIP             0
# RoomService     0
# FoodCourt       0
# ShoppingMall    0
# Spa             0
# VRDeck          0
# dtype: int64

# %%
df_test = df_test.interpolate()

# %%
df_test = df_test.fillna(False)

# %%
df_test = df_test.drop('PassengerId', axis=1)

# %%
y_pred = full_model.predict(df_test)

# %%
y_pred
# Out:
# array([ True, False,  True, ...,  True,  True,  True])

# %%
sub = pd.read_csv('sample_submission.csv')

# %%
sub['Transported'] = y_pred

# %%
sub.to_csv('ttt.csv', index=False, index_label=False)
